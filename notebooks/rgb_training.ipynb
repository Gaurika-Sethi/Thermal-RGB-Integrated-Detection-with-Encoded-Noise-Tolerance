# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
dataset_path = "/content/drive/MyDrive/thermal_vision_project/datasets/coco_subset"

print(os.path.exists(dataset_path))
# Out:
# True

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
model = YOLO("yolov8s.pt")

# %%
model.train(
    data="/content/drive/MyDrive/thermal_vision_project/configs/rgb.yaml",
    epochs=20,
    imgsz=640,
    batch=8,
    workers=2,
    project="/content/drive/MyDrive/thermal_vision_project/training_outputs",
    name="rgb_yolov8s_v1"
)
# Out:
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 61.9±32.2 MB/s, size: 167.2 KB)
# val: Scanning /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/labels/val.cache... 1000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 381.3Mit/s 0.0s
# val: /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000785.jpg: 1 duplicate labels removed
# val: /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000872.jpg: 2 duplicate labels removed
# val: /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000885.jpg: 8 duplicate labels removed
# val: /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001000.jpg: 12 duplicate labels removed
# ...

# %%
results = model.predict(
    source="/content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val",
    conf=0.25,
    save=True
)
# Out:
# image 1/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000785.jpg: 448x640 1 person, 46.6ms
# image 2/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000872.jpg: 640x640 2 persons, 16.6ms
# image 3/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000885.jpg: 448x640 6 persons, 13.2ms
# image 4/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001000.jpg: 480x640 13 persons, 49.1ms
# image 5/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001490.jpg: 320x640 1 person, 47.8ms
# image 6/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000002261.jpg: 448x640 1 person, 13.0ms
# image 7/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000002299.jpg: 416x640 35 persons, 47.9ms
# ...

# %%
# !ls /content/drive/MyDrive/thermal_vision_project/training_outputs
# Out:
# rgb_yolov8s_v1-3

# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# False

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

# %%
results = model.train(
    data="/content/drive/MyDrive/thermal_vision_project/configs/rgb.yaml",
    epochs=20,
    imgsz=640,
    batch=8,
    workers=2,
    device=0,
    pretrained=True,
    project="/content/drive/MyDrive/thermal_vision_project/training_outputs",
    name="rgb_yolov8s_v1",
    exist_ok=True
)
# Out:
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/drive/MyDrive/thermal_vision_project/training_outputs/rgb_yolov8s_v1
# Out:
# args.yaml			 results.csv	      val_batch0_labels.jpg
# BoxF1_curve.png			 results.png	      val_batch0_pred.jpg
# BoxP_curve.png			 train_batch0.jpg     val_batch1_labels.jpg
# BoxPR_curve.png			 train_batch1.jpg     val_batch1_pred.jpg
# BoxR_curve.png			 train_batch2.jpg     val_batch2_labels.jpg
# confusion_matrix_normalized.png  train_batch6250.jpg  val_batch2_pred.jpg
# confusion_matrix.png		 train_batch6251.jpg  weights
# labels.jpg			 train_batch6252.jpg

# %% [markdown]
# **Interferance Scripts**

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

from ultralytics import YOLO
# Out:
# Mounted at /content/drive

# %%
model = YOLO(
    "/content/drive/MyDrive/thermal_vision_project/training_outputs/rgb_yolov8s_v1/weights/best.pt"
)

# %%
results = model.predict(
    source="/content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val",
    conf=0.25,
    save=True,
    project="/content/drive/MyDrive/thermal_vision_project/inference_outputs",
    name="rgb_eval_v1",
    exist_ok=True
)
# Out:
# image 1/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000785.jpg: 448x640 1 person, 45.8ms
# image 2/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000872.jpg: 640x640 2 persons, 17.2ms
# image 3/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000885.jpg: 448x640 6 persons, 13.4ms
# image 4/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001000.jpg: 480x640 13 persons, 45.7ms
# image 5/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001490.jpg: 320x640 1 person, 46.5ms
# image 6/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000002261.jpg: 448x640 1 person, 13.5ms
# image 7/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000002299.jpg: 416x640 35 persons, 48.2ms
# ...

# %% [markdown]
#  **Compare Against Pretrained **YOLO****

# %%
pretrained_model = YOLO("yolov8s.pt")

# %%
pretrained_results = pretrained_model.predict(
    source="/content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val",
    conf=0.25,
    save=True,
    project="/content/drive/MyDrive/thermal_vision_project/inference_outputs",
    name="rgb_pretrained_eval",
    exist_ok=True
)
# Out:
# image 1/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000785.jpg: 448x640 1 person, 1 skis, 13.6ms
# image 2/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000872.jpg: 640x640 2 persons, 1 sports ball, 16.9ms
# image 3/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000000885.jpg: 448x640 8 persons, 1 sports ball, 1 tennis racket, 13.3ms
# image 4/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001000.jpg: 480x640 14 persons, 1 handbag, 2 tennis rackets, 13.6ms
# image 5/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000001490.jpg: 320x640 1 person, 1 surfboard, 11.1ms
# image 6/1000 /content/drive/MyDrive/thermal_vision_project/datasets/coco_subset/images/val/000000002261.jpg: 448x640 1 person, 13.3ms
# ...
