# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurika-Sethi/Thermal-RGB-Integrated-Detection-with-Encoded-Noise-Tolerance/blob/main/notebooks/rgb_detection_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Gaurika-Sethi/Thermal-RGB-Integrated-Detection-with-Encoded-Noise-Tolerance.git
# Out:
# Cloning into 'Thermal-RGB-Integrated-Detection-with-Encoded-Noise-Tolerance'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 214 (delta 20), reused 201 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (214/214), 2.73 MiB | 14.84 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
import os

video_path = "/content/drive/MyDrive/thermal project/Thermal-RGB-Integrated-Detection-with-Encoded-Noise-Tolerance/data/raw/sample.mp4"

print(os.path.exists(video_path))
# Out:
# True

# %%
import cv2

cap = cv2.VideoCapture(video_path)

print(cap.isOpened())

cap.release()
# Out:
# True
